# %%
''' fusions... 
    pulling from new_fastqs.ipynb here '''

# %%
import pandas as pd

# %%
star_out_path = 's3://darmanis-group/singlecell_lungadeno/non_immune/nonImmune_fastqs_9.27/STAR-fus_out/'

# %%
! aws s3 ls $star_out_path > out

# %%
star_out_df = pd.read_csv('out', names=['is_prefix', 'file'], delim_whitespace=True)
star_out_df
# Out:
#       is_prefix             file
# 0           PRE  A10_1001000293/
# 1           PRE  A10_1001000295/
# 2           PRE  A10_1001000296/
# 3           PRE  A10_1001000297/
# 4           PRE  A10_1001000329/
# 5           PRE  A10_1001000407/
# 6           PRE  A10_1001000408/
# 7           PRE  A10_1001000409/
# 8           PRE  A10_1001000410/
# 9           PRE  A10_1001000412/
# 10          PRE     A10_B000274/
# 11          PRE     A10_B000420/
# 12          PRE     A10_B000863/
# 13          PRE     A10_B000894/
# 14          PRE     A10_B001008/
# 15          PRE     A10_B001016/
# 16          PRE     A10_B001470/
# 17          PRE     A10_B001474/
# 18          PRE     A10_B001545/
# 19          PRE     A10_B001556/
# 20          PRE     A10_B001608/
# 21          PRE     A10_B002073/
# 22          PRE     A10_B002074/
# 23          PRE     A10_B002078/
# 24          PRE     A10_B002572/
# 25          PRE     A10_B003048/
# 26          PRE     A10_B003067/
# ...

# %%
star_out_l = list(star_out_df.file)
star_out_l = [x.strip('/') for x in star_out_l]
star_out_l
# Out:
# ['A10_1001000293',
#  'A10_1001000295',
#  'A10_1001000296',
#  'A10_1001000297',
#  'A10_1001000329',
#  'A10_1001000407',
#  'A10_1001000408',
#  'A10_1001000409',
#  'A10_1001000410',
#  'A10_1001000412',
#  'A10_B000274',
#  'A10_B000420',
#  'A10_B000863',
#  'A10_B000894',
#  'A10_B001008',
#  'A10_B001016',
#  'A10_B001470',
#  'A10_B001474',
#  'A10_B001545',
#  'A10_B001556',
#  'A10_B001608',
#  'A10_B002073',
#  'A10_B002074',
#  'A10_B002078',
#  'A10_B002572',
#  'A10_B003048',
#  'A10_B003067',
#  'A10_B003070',
#  'A10_B003071',
#  'A10_B003115',
#  'A10_B003117',
#  'A10_B003120',
#  'A10_B003121',
#  'A10_B003125',
#  'A10_B003126',
#  'A10_B003187',
#  'A10_B003518',
#  'A10_B003523',
#  'A10_B003527',
#  'A10_B003528',
#  'A10_B003529',
#  'A10_B003588',
#  'A10_B003642',
#  'A10_B003643',
#  'A10_B003646',
#  'A10_B003648',
#  'A10_B003775',
#  'A10_B003776',
#  'A10_B003777',
#  'A10_B003894',
#  'A10_B003920',
#  'A11_1001000293',
#  'A11_1001000294',
# ...

# %%
len(star_out_l)
# Out:
# 18570

# %%
missing_cells_df = pd.read_csv('missing_cells_2.27.20.csv', names=['cell'])
missing_cells_df
# Out:
#                cell
# 0                 0
# 1       M19_B002073
# 2       A10_B001007
# 3        K2_B000429
# 4       G15_B001556
# 5       J21_B002572
# 6        P1_B002568
# 7       A22_B001007
# 8        P6_B003656
# 9       M15_B001543
# 10      B15_B001543
# 11      H20_B003528
# 12       K6_B002572
# 13    A1_1001000295
# 14      H19_B003472
# 15      K20_B002572
# 16       K5_B003528
# 17      C17_B000577
# 18      M18_B001543
# 19      L11_B002572
# 20    E2_1001000408
# 21      P18_B001007
# 22       B5_B002572
# 23       O7_B001797
# 24       C9_B001007
# 25      P14_B002572
# 26      E21_B003528
# 27       O3_B002572
# 28      J20_B002568
# 29      G15_B002572
# ...             ...
# 1009    B22_B003528
# 1010     H2_B003528
# 1011    P21_B003775
# 1012     D7_B003528
# 1013    D15_B003093
# 1014    C10_B001007
# 1015    A18_B002572
# 1016    F15_B001007
# 1017    N13_B002572
# 1018    I13_B002079
# 1019    O20_B000901
# 1020    D17_B003528
# 1021    J19_B002572
# ...

# %%
missing_star_list = set(missing_cells_df.cell) - set(star_out_l)
missing_star_list
# Out:
# {'0',
#  'A10_B001007',
#  'A11_B001007',
#  'A16_B001007',
#  'A18_B001007',
#  'A1_B001007',
#  'A1_B001551',
#  'A21_B001007',
#  'A22_B001007',
#  'A3_B001007',
#  'A5_B001007',
#  'A5_B001558',
#  'A5_B003995',
#  'A7_B001007',
#  'A8_B001007',
#  'A9_B001007',
#  'B10_B001007',
#  'B11_B001007',
#  'B12_B001007',
#  'B13_B001007',
#  'B15_B001007',
#  'B17_B001007',
#  'B17_B001557',
#  'B18_B001557',
#  'B1_B001007',
#  'B1_B001551',
#  'B20_B001007',
#  'B20_B001557',
#  'B21_B001557',
#  'B2_B001007',
#  'B2_B001551',
#  'B3_B001007',
#  'B4_B001007',
#  'B5_B001007',
#  'B6_B001007',
#  'B8_B001007',
#  'B9_B001007',
#  'C10_B001007',
#  'C11_B001007',
#  'C14_B003103',
#  'C17_B001007',
#  'C18_B001007',
#  'C19_B001007',
#  'C19_B002572',
#  'C1_B001007',
#  'C20_B001007',
#  'C2_B001007',
#  'C4_B001007',
#  'C4_B001557',
#  'C5_B001007',
#  'C6_B001551',
#  'C7_B001007',
#  'C9_B001007',
#  'D10_B003995',
#  'D11_B001007',
#  'D12_B001007',
#  'D14_B001007',
# ...

# %%
missing_star_list = list(missing_star_list)
del missing_star_list[0]
missing_star_list
# Out:
# ['G15_B001007',
#  'I14_B001007',
#  'C4_B001007',
#  'B1_B001007',
#  'A16_B001007',
#  'H12_B001007',
#  'K3_B001007',
#  'I11_B001551',
#  'L3_B001007',
#  'L8_B001007',
#  'N4_B001007',
#  'C19_B001007',
#  'B10_B001007',
#  'K4_B001007',
#  'A9_B001007',
#  'A22_B001007',
#  'B5_B001007',
#  'H22_B001551',
#  'L9_B001548',
#  'K11_B001007',
#  'M10_B001007',
#  'F16_B001007',
#  'N1_B001007',
#  'J9_B001007',
#  'F7_B001007',
#  'B15_B001007',
#  'D7_B001551',
#  'H9_B001007',
#  'H5_B001007',
#  'D10_B003995',
#  'I5_B001007',
#  'J8_B001007',
#  'N11_B001007',
#  'P17_B001007',
#  'N15_B001007',
#  'I9_B001007',
#  'G11_B001007',
#  'F20_B001007',
#  'G15_B001548',
#  'F5_B001007',
#  'N3_B001007',
#  'G22_B001548',
#  'M5_B001007',
#  'G21_B001007',
#  'F12_B001007',
#  'C9_B001007',
#  'B8_B001007',
#  'E10_B001007',
#  'F1_B001007',
#  'G14_B001007',
#  'O14_B001007',
#  'D3_B001007',
#  'D14_B001007',
#  'J19_B001007',
#  'M15_B001007',
#  'G1_B003068',
#  'A10_B001007',
# ...

# %%
# ok so 248 that still need fusions
len(missing_star_list)
# Out:
# 248

# %%
#///////////////////////////////////////////////////////////////////////////////////////
#///////////////////////////////////////////////////////////////////////////////////////
#///////////////////////////////////////////////////////////////////////////////////////

# %%
# lets get cmds for dwlding them
s3_path = 's3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/'

# %%
cmds = []
for x in missing_star_list:
    cmd0 = 'aws s3 cp ' + s3_path + x + '_R1.fastq.gz .'
    cmd1 = 'aws s3 cp ' + s3_path + x + '_R2.fastq.gz .'
    cmds.append(cmd0)
    cmds.append(cmd1)

# %%
cmds
# Out:
# ['aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/G15_B001007_R1.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/G15_B001007_R2.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/I14_B001007_R1.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/I14_B001007_R2.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/C4_B001007_R1.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/C4_B001007_R2.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/B1_B001007_R1.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/B1_B001007_R2.fastq.gz .',
#  'aws s3 cp s3://darmanis-group/singlecell_lungadeno/rawdata/fastq_all/rename/A16_B001007_R1.fastq.gz .',
# ...
