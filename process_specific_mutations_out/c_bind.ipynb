# %%
''' ok lets paste em bitches together '''

# %%
import pandas as pd
import os

# %%
big_df = pd.read_csv('EGFR_new_cells_out.csv_AA.csv', names=['cell', 'EGFR'])
rundir = '/home/ubuntu/code/cerebra/cerebra/tmp/scVCF_filtered_all/'

big_df.cell = [x.replace(rundir, '') for x in list(big_df.cell)]

big_df.index = big_df.cell
big_df = big_df[['EGFR']]
big_df
# Out:
#                            EGFR
# cell
# I1_B002558                   []
# C9_B000561                   []
# E3_B002570                   []
# F7_B001546                   []
# O16_B003183                  []
# J18_B003588                  []
# G11_B000561                  []
# L3_B000561                   []
# E14_B003183                  []
# B19_B003588                  []
# H12_B001546                  []
# F16_B000568                  []
# I14_B003183                  []
# H8_B001546                   []
# A17_B000563                  []
# F17_B000563                  []
# O20_B003179                  []
# H15_B000563                  []
# C2_B000568                   []
# N16_B000563                  []
# K7_B000561                   []
# H14_B003183  ['Q787Q', 'L858R']
# C13_B003183           ['Q787Q']
# C6_B000561                   []
# C11_B000568                  []
# I12_B002570                  []
# N8_B000561                   []
# H9_B002558                   []
# ...

# %%
rundir = '/home/ubuntu/code/cerebra/cerebra/tmp/scVCF_filtered_all/'

for f in os.listdir('.'):
    if '.csv' in f:
        curr_mut = f.split('_')[0]
        path = os.getcwd() + '/' + f
        #print(path)
        curr_df = pd.read_csv(path, names=['cell', 'mut'])
        curr_df.cell = [x.replace(rundir, '') for x in list(curr_df.cell)]
        
        big_df[curr_mut] = curr_df.mut

# %%
# ayyyyyyyy
big_df
# Out:
#             EGFR CCDC6 TET2  KDR MYCL NFE2L2 RARA  BTK STK11 DDR2  ...  \
# cell                                                               ...
# I1_B002558   NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# C9_B000561   NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# E3_B002570   NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# F7_B001546   NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# O16_B003183  NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# J18_B003588  NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# G11_B000561  NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# L3_B000561   NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# E14_B003183  NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# B19_B003588  NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# H12_B001546  NaN   NaN  NaN  NaN  NaN    NaN  NaN  NaN   NaN  NaN  ...
# ...
